# %%
H2O_cp_scaler = joblib.load('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/H2O/Trained Model/H2O_cp_model_scaler.save') 
H2O_cp_model = load_model('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/H2O/Trained Model/H2O_cp_model.h5')

O2_cp_scaler = joblib.load('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/O2/Trained Model/O2_cp_model_scaler.save') 
O2_cp_model = load_model('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/O2/Trained Model/O2_cp_model.h5')

CO2_cp_scaler = joblib.load('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/CO2/Trained Model/CO2_cp_model_scaler.save') 
CO2_cp_model = load_model('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/CO2/Trained Model/CO2_cp_model.h5')

N2_cp_scaler = joblib.load('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/N2/Trained Model/N2_cp_model_scaler.save') 
N2_cp_model = load_model('/Users/2923185/Desktop/New NextMGT/Codes/T100 MGT - Steady State/Flow Properties/Models/N2/Trained Model/N2_cp_model.h5')
